# %%
import pandas as pd

# Replace 'your_dataset.csv' with the path to your dataset file
dataset_path = 'ECOMMRecords2020.csv'
data = pd.read_csv(dataset_path)

# Display the first few rows of the dataset
data.head()
# Out:
#     OrderDate  RowID         OrderID        ShipMode CustomerID      Segment  \
# 0  2020-01-01    849  CA-2017-107503  Standard Class   GA-14725     Consumer
# 1  2020-01-01   4010  CA-2017-144463  Standard Class   SC-20725     Consumer
# 2  2020-01-01   6683  CA-2017-154466     First Class   DP-13390  Home Office
# 3  2020-01-01   8070  CA-2017-151750  Standard Class   JM-15250     Consumer
# 4  2020-01-01   8071  CA-2017-151750  Standard Class   JM-15250     Consumer
#
#          Country         City       State  PostalCode   Region  \
# 0  United States       Lorain        Ohio       44052     East
# 1  United States  Los Angeles  California       90036     West
# 2  United States     Franklin   Wisconsin       53132  Central
# 3  United States   Huntsville       Texas       77340  Central
# 4  United States   Huntsville       Texas       77340  Central
#
#          ProductID         Category  SubCategory  \
# 0  FUR-FU-10003878        Furniture  Furnishings
# 1  FUR-FU-10001215        Furniture  Furnishings
# 2  OFF-BI-10002012  Office Supplies      Binders
# 3  OFF-ST-10002743  Office Supplies      Storage
# 4  FUR-FU-10002116        Furniture  Furnishings
#
#                                          ProductName    Sales  Quantity  \
# 0                   Linden 10 Round Wall Clock Black   48.896         4
# 1  Howard Miller 11-1/2 Diameter Brentwood Wall C...  474.430        11
# 2            Wilson Jones Easy Flow II Sheet Lifters    3.600         2
# 3                      SAFCO Boltless Steel Shelving  454.560         5
# 4  Tenex Carpeted Granite-Look or Clear Contempor...  141.420         5
#
#    Discount    Profit
# 0       0.2    8.5568
# 1       0.0  199.2606
# 2       0.0    1.7280
# 3       0.2 -107.9580
# 4       0.6 -187.3815

# %%
data.dates = pd.date_range("20130101", periods=6)

# koeffisent = standard / mean
data["Cost"] = (data["Sales"] - data["Profit"])

data["Revenue"] = (data["Profit"]/data["Quantity"])
data["Price"] = (data["Sales"]/data["Quantity"])

data["Margin"] = (data["Profit"]/data["Sales"])

# use groupby

data
# Out:
# /var/folders/7k/3nkpnjw91q347lwnd4y3wxk40000gn/T/ipykernel_59950/123182999.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.dates = pd.date_range("20130101", periods=6)
#        OrderDate  RowID         OrderID        ShipMode CustomerID  \
# 0     2020-01-01    849  CA-2017-107503  Standard Class   GA-14725
# 1     2020-01-01   4010  CA-2017-144463  Standard Class   SC-20725
# 2     2020-01-01   6683  CA-2017-154466     First Class   DP-13390
# 3     2020-01-01   8070  CA-2017-151750  Standard Class   JM-15250
# 4     2020-01-01   8071  CA-2017-151750  Standard Class   JM-15250
# ...          ...    ...             ...             ...        ...
# 3307  2020-12-30    908  CA-2017-143259  Standard Class   PO-18865
# 3308  2020-12-30    909  CA-2017-143259  Standard Class   PO-18865
# 3309  2020-12-30   1297  CA-2017-115427  Standard Class   EB-13975
# 3310  2020-12-30   1298  CA-2017-115427  Standard Class   EB-13975
# 3311  2020-12-30   5092  CA-2017-156720  Standard Class   JM-15580
#
#           Segment        Country           City       State  PostalCode  ...  \
# 0        Consumer  United States         Lorain        Ohio       44052  ...
# 1        Consumer  United States    Los Angeles  California       90036  ...
# 2     Home Office  United States       Franklin   Wisconsin       53132  ...
# 3        Consumer  United States     Huntsville       Texas       77340  ...
# 4        Consumer  United States     Huntsville       Texas       77340  ...
# ...           ...            ...            ...         ...         ...  ...
# 3307     Consumer  United States  New York City    New York       10009  ...
# 3308     Consumer  United States  New York City    New York       10009  ...
# 3309    Corporate  United States      Fairfield  California       94533  ...
# 3310    Corporate  United States      Fairfield  California       94533  ...
# 3311     Consumer  United States       Loveland    Colorado       80538  ...
#
#       SubCategory                                        ProductName    Sales  \
# 0     Furnishings                   Linden 10 Round Wall Clock Black   48.896
# 1     Furnishings  Howard Miller 11-1/2 Diameter Brentwood Wall C...  474.430
# 2         Binders            Wilson Jones Easy Flow II Sheet Lifters    3.600
# 3         Storage                      SAFCO Boltless Steel Shelving  454.560
# 4     Furnishings  Tenex Carpeted Granite-Look or Clear Contempor...  141.420
# ...           ...                                                ...      ...
# 3307       Phones                          Gear Head AU3700S Headset   90.930
# 3308      Binders               Wilson Jones Legal Size Ring Binders   52.776
# 3309      Binders     Cardinal Slant-D Ring Binder Heavy Gauge Vinyl   13.904
# 3310      Binders                                 GBC Binding covers   20.720
# 3311    Fasteners                                Bagged Rubber Bands    3.024
#
#      Quantity Discount    Profit      Cost  Revenue   Price  Margin
# 0           4      0.2    8.5568   40.3392   2.1392  12.224  0.1750
# 1          11      0.0  199.2606  275.1694  18.1146  43.130  0.4200
# 2           2      0.0    1.7280    1.8720   0.8640   1.800  0.4800
# 3           5      0.2 -107.9580  562.5180 -21.5916  90.912 -0.2375
# 4           5      0.6 -187.3815  328.8015 -37.4763  28.284 -1.3250
# ...       ...      ...       ...       ...      ...     ...     ...
# 3307        7      0.0    2.7279   88.2021   0.3897  12.990  0.0300
# 3308        3      0.2   19.7910   32.9850   6.5970  17.592  0.3750
# 3309        2      0.2    4.5188    9.3852   2.2594   6.952  0.3250
# 3310        2      0.2    6.4750   14.2450   3.2375  10.360  0.3125
# 3311        3      0.2   -0.6048    3.6288  -0.2016   1.008 -0.2000
#
# [3312 rows x 23 columns]

# %%
mean = data.groupby("Category")['Margin'].mean()
std = data.groupby("Category")['Margin'].std()

df = pd.concat([mean, std], axis=1).reset_index()
df.columns = ["Category", "Mean", "Std"]  
df["CoeffisiantOfVariation"] = (df["Std"]/df["Mean"])**2  

mean_of_group = data.groupby("SubCategory")['Margin'].mean()

def get_coefficient_variation(data, feature):
    group_data = data.groupby(feature)
    mean = data.groupby(feature)['Margin'].mean()
    std = data.groupby(feature)['Margin'].std()
    category =(std/mean)**2   
    return category

category = get_coefficient_variation(data, "Category")
subcategory = get_coefficient_variation(data, "SubCategory")


category
#subcategory
# Out:
# Category
# Furniture          84.568818
# Office Supplies    19.615620
# Technology          1.866943
# Name: Margin, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder



data.dtypes


# Example categorical dat

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the data to convert categories to numbers
data["labelcategory"] = label_encoder.fit_transform(data["Category"])

features = ["RowID",            
"PostalCode",       
"Sales",          
"Quantity",         
"Discount",       
"Profit",         
"Cost",           
"Revenue",        
"Price",          
"Cluster",          
"Margin",
"labelcategory"
]   


corr_matrix =  data[features].corr()

plt.figure(figsize=(10, 8))  # Adjust the size if needed
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.show()

# %%
def split_data(feature, data):
    categories = list(data[feature].unique())
    dataframes = {}

    for c in categories: 
        df = data[data[feature] == c]
        dataframes[c] = df
    
    return dataframes



grouped_dataframes = split_data("Category", data)
grouped_dataframes.keys()

data.describe()
# Out:
#              RowID    PostalCode         Sales     Quantity     Discount  \
# count  3312.000000   3312.000000   3312.000000  3312.000000  3312.000000
# mean   5087.107488  56186.515097    221.381418     3.766908     0.156467
# std    2817.482266  31980.375516    585.257531     2.221776     0.207429
# min      13.000000   1841.000000      0.444000     1.000000     0.000000
# 25%    2655.750000  27978.750000     17.018000     2.000000     0.000000
# 50%    5183.500000  60472.500000     53.810000     3.000000     0.200000
# 75%    7498.250000  90032.000000    205.105700     5.000000     0.200000
# max    9994.000000  99301.000000  13999.960000    14.000000     0.800000
#
#             Profit          Cost      Revenue        Price       Margin  \
# count  3312.000000   3312.000000  3312.000000  3312.000000  3312.000000
# mean     28.212340    193.169078     7.906817    60.392382     0.115981
# std     241.864342    500.323930    61.491808   152.194508     0.481265
# min   -3839.990400      0.554400  -959.997600     0.336000    -2.750000
# 25%       1.763200     12.527625     0.707625     5.430000     0.075000
# 50%       8.296800     42.414300     2.698600    15.992000     0.270000
# 75%      28.315125    175.990000     8.409150    60.972500     0.362500
# max    6719.980800  11839.970400  1679.995200  3499.990000     0.500000
#
#            Cluster  labelcategory
# count  3312.000000    3312.000000
# mean      0.406703       0.981280
# std       0.493134       0.628729
# min       0.000000       0.000000
# 25%       0.000000       1.000000
# 50%       0.000000       1.000000
# 75%       1.000000       1.000000
# max       2.000000       2.000000

# %%
def get_avg_margin(feature):
    means = data.groupby("ProductName")["Margin"].mean().reset_index()
    means.columns = ["ProductName", "MeanMarging"]
    means.columns = ["ProductName", "MeanMarging"]
    new_df = pd.merge(means, data, on = "ProductName")
    return new_df

avg_mean = get_avg_margin("Category")
avg_mean

def avg_cost_per_unit(dataframe):
    dataframe["CostPerUnit"] = dataframe["Cost"]/dataframe["Quantity"]
    means = dataframe.groupby("ProductName")["CostPerUnit"].mean().reset_index()
    means.columns = ["ProductName", "MeanCostPerUnit"]
    new_df = pd.merge(means, dataframe, on = "ProductName")
    return new_df

#def avg_sales_last_3_month

# %%
df = grouped_dataframes["Technology"].copy()
df
# Out:
#        OrderDate  RowID         OrderID        ShipMode CustomerID    Segment  \
# 10    2020-01-02   1341  CA-2017-113481     First Class   AS-10045  Corporate
# 17    2020-01-02   9686  CA-2017-118668    Second Class   FW-14395  Corporate
# 22    2020-01-07    978  CA-2017-159366     First Class   BW-11110  Corporate
# 39    2020-01-14   1184  CA-2017-138779     First Class   RB-19570   Consumer
# 40    2020-01-14   4165  US-2017-106131     First Class   TP-21565  Corporate
# ...          ...    ...             ...             ...        ...        ...
# 3267  2020-12-25   9377  CA-2017-108756  Standard Class   PO-18865   Consumer
# 3272  2020-12-27   2570  CA-2017-134404        Same Day   DR-12880  Corporate
# 3278  2020-12-28    574  CA-2017-164826  Standard Class   JF-15415   Consumer
# 3294  2020-12-29   1879  CA-2017-118885  Standard Class   JG-15160   Consumer
# 3307  2020-12-30    908  CA-2017-143259  Standard Class   PO-18865   Consumer
#
#             Country           City           State  PostalCode  ...  \
# 10    United States   Jacksonville  North Carolina       28540  ...
# 17    United States    Los Angeles      California       90032  ...
# 22    United States        Detroit        Michigan       48205  ...
# 39    United States   Jacksonville  North Carolina       28540  ...
# 40    United States         Aurora        Colorado       80013  ...
# ...             ...            ...             ...         ...  ...
# 3267  United States    East Orange      New Jersey        7017  ...
# 3272  United States         Newark            Ohio       43055  ...
# 3278  United States  New York City        New York       10024  ...
# 3294  United States    Los Angeles      California       90049  ...
# 3307  United States  New York City        New York       10009  ...
#
#       SubCategory                                        ProductName  \
# 10       Machines  Cisco CP-7937G Unified IP Conference Station P...
# 17    Accessories  Kensington K72356US Mouse-in-a-Box USB Desktop...
# 22       Machines          Lexmark MX611dhe Monochrome Laser Printer
# 39         Phones  Sannysis Cute Owl Design Soft Skin Case Cover ...
# 40    Accessories     Imation8GB Mini TravelDrive USB 2.0Flash Drive
# ...           ...                                                ...
# 3267  Accessories                    Memorex Micro Travel Drive 4 GB
# 3272       Phones                             AT&T 1080 Corded phone
# 3278       Phones  Cush Cases Heavy Duty Rugged Cover Case for Sa...
# 3294       Phones                                   Adtran 1202752G1
# 3307       Phones                          Gear Head AU3700S Headset
#
#          Sales Quantity Discount    Profit       Cost   Revenue     Price  \
# 10     695.700        2      0.5  -27.8280   723.5280  -13.9140   347.850
# 17      16.590        1      0.0    5.8065    10.7835    5.8065    16.590
# 22    3059.982        2      0.1  679.9960  2379.9860  339.9980  1529.991
# 39       7.920        5      0.2    0.6930     7.2270    0.1386     1.584
# 40     169.064        7      0.2  -14.7931   183.8571   -2.1133    24.152
# ...        ...      ...      ...       ...        ...       ...       ...
# 3267    31.800        3      0.0   13.6740    18.1260    4.5580    10.600
# 3272   164.388        2      0.4  -35.6174   200.0054  -17.8087    82.194
# 3278    14.850        3      0.0    4.0095    10.8405    1.3365     4.950
# 3294   302.376        3      0.2   22.6782   279.6978    7.5594   100.792
# 3307    90.930        7      0.0    2.7279    88.2021    0.3897    12.990
#
#         Margin
# 10   -0.040000
# 17    0.350000
# 22    0.222222
# 39    0.087500
# 40   -0.087500
# ...        ...
# 3267  0.430000
# 3272 -0.216667
# 3278  0.270000
# 3294  0.075000
# 3307  0.030000
#
# [624 rows x 23 columns]

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
X, y = make_blobs(random_state=42)
kmeans = KMeans(n_clusters=2, random_state=42)
silhouette_score(X, kmeans.fit_predict(X))
# Out:
# 0.496137786540463

# %%
category = data

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Replace 'your_dataset.csv' with the path to your dataset file
dataset_path = 'ECOMMRecords2020.csv'
data = pd.read_csv(dataset_path)

# Create new features as done previously
data["Cost"] = (data["Sales"] - data["Profit"])
data["Revenue"] = (data["Profit"] / data["Quantity"])
data["Price"] = (data["Sales"] / data["Quantity"])
data["Margin"] = (data["Profit"] / data["Sales"])

# Step 1: One-hot encode the "Category" feature
data_encoded = pd.get_dummies(data, columns=["Category"], drop_first=True)

# Step 2: Select relevant numerical features for clustering
features = ['Sales', 'Profit', 'Quantity', 'Cost', 'Revenue', 'Price'] + list(data_encoded.columns[data_encoded.columns.str.startswith('Category_')])

# Extract only the selected features
X = data_encoded[features]

# Step 3: Scale the data before applying K-Means
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Perform K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)  # You can adjust the number of clusters as needed
kmeans.fit(X_scaled)

# Step 5: Calculate silhouette score
silhouette_avg = silhouette_score(X_scaled, kmeans.labels_)
print(f'Silhouette Score: {silhouette_avg}')

# Step 6: Add the cluster labels to the original dataset for further analysis
data['Cluster'] = kmeans.labels_

# Display the first few rows of the dataset with cluster labels
data.head()
# Out:
# Silhouette Score: 0.4166313697706286
#     OrderDate  RowID         OrderID        ShipMode CustomerID      Segment  \
# 0  2020-01-01    849  CA-2017-107503  Standard Class   GA-14725     Consumer
# 1  2020-01-01   4010  CA-2017-144463  Standard Class   SC-20725     Consumer
# 2  2020-01-01   6683  CA-2017-154466     First Class   DP-13390  Home Office
# 3  2020-01-01   8070  CA-2017-151750  Standard Class   JM-15250     Consumer
# 4  2020-01-01   8071  CA-2017-151750  Standard Class   JM-15250     Consumer
#
#          Country         City       State  PostalCode  ...  \
# 0  United States       Lorain        Ohio       44052  ...
# 1  United States  Los Angeles  California       90036  ...
# 2  United States     Franklin   Wisconsin       53132  ...
# 3  United States   Huntsville       Texas       77340  ...
# 4  United States   Huntsville       Texas       77340  ...
#
#                                          ProductName    Sales Quantity  \
# 0                   Linden 10 Round Wall Clock Black   48.896        4
# 1  Howard Miller 11-1/2 Diameter Brentwood Wall C...  474.430       11
# 2            Wilson Jones Easy Flow II Sheet Lifters    3.600        2
# 3                      SAFCO Boltless Steel Shelving  454.560        5
# 4  Tenex Carpeted Granite-Look or Clear Contempor...  141.420        5
#
#   Discount    Profit      Cost  Revenue   Price  Margin  Cluster
# 0      0.2    8.5568   40.3392   2.1392  12.224  0.1750        1
# 1      0.0  199.2606  275.1694  18.1146  43.130  0.4200        1
# 2      0.0    1.7280    1.8720   0.8640   1.800  0.4800        0
# 3      0.2 -107.9580  562.5180 -21.5916  90.912 -0.2375        0
# 4      0.6 -187.3815  328.8015 -37.4763  28.284 -1.3250        1
#
# [5 rows x 24 columns]

# %%
print(data.columns
      )
# Out:
# Index(['OrderDate', 'RowID', 'OrderID', 'ShipMode', 'CustomerID', 'Segment',
#        'Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID',
#        'Category', 'SubCategory', 'ProductName', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Cost', 'Revenue', 'Price', 'Margin', 'Cluster'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Select two features to visualize (for example: 'Sales' and 'Profit')
plt.figure(figsize=(10, 6))

# Scatter plot where color represents cluster label
plt.scatter(data['Sales'], data['Profit'], c=data['Cluster'], cmap='viridis')

# Add labels and title
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Clusters based on Sales and Profit')
plt.colorbar(label='Cluster')
plt.show()
